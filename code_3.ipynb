# 2     0.853404  0.580997  0.402628  0.431900  0.464468  0.691700
# 3    -1.140255 -1.420735 -1.883106 -1.811040 -2.196093 -1.704123
# 4    -0.717006 -0.565019 -0.644409 -0.973549 -0.840768 -0.327801
# ...        ...       ...       ...       ...       ...       ...
# 7321  1.194198  1.177196  1.140504  1.110838  1.083161  1.053034
# 7322  1.220874  1.191414  1.167158  1.134478  1.104766  1.078077
# 7323  1.239488  1.213346  1.189792  1.165011  1.131039  1.105254
# 7324  1.216507  1.190271  1.169392  1.136811  1.110023  1.092333
# 7325  1.233420  1.210825  1.164077  1.132695  1.097706  1.058586
#
# [7326 rows x 52 columns]

# %%
train = train.drop(columns=['y','w'])

# %%
features_and_targets = pd.concat([train, targets], axis=1)

# %%
corr_matrix = features_and_targets.corr()
corr_matrix['y']
# Out:
# 0     0.613172
# 1     0.618793
# 2     0.621057
# 3     0.614287
# 4     0.602994
# 5     0.589865
# 6     0.584518
# 7     0.580042
# 8     0.579152
# 9     0.588522
# 10    0.601310
# 11    0.612443
# 12    0.626453
# 13    0.642289
# 14    0.657419
# 15    0.666290
# 16    0.673230
# 17    0.677283
# 18    0.681082
# 19    0.679991
# 20    0.683424
# 21    0.688972
# 22    0.701411
# 23    0.715419
# 24    0.726833
# 25    0.745667
# 26    0.765639
# 27    0.783774
# 28    0.802625
# 29    0.819507
# 30    0.828819
# 31    0.831443
# 32    0.826190
# 33    0.808870
# 34    0.779100
# 35    0.743946
# 36    0.709549
# 37    0.683334
# 38    0.664611
# 39    0.656926
# 40    0.658175
# 41    0.670157
# 42    0.684724
# 43    0.708149
# 44    0.745744
# 45    0.790237
# 46    0.843251
# 47    0.898601
# 48    0.944832
# 49    0.977203
# y     1.000000
# Name: y, dtype: float64

# %%
train_set, test_set = train_test_split(features_and_targets,test_size=0.2,train_size=0.8)

# %%
train_set_features = train_set.drop(columns="y")
train_set_targets = train_set["y"]

lin_reg = LinearRegression().fit(train_set_features,train_set_targets)

#len(train_set_features)

# %%
test_set_features = test_set.drop(columns="y")
test_set_targets = test_set["y"]

train_predictions = lin_reg.predict(train_set_features)
test_predictions = lin_reg.predict(test_set_features)

# We can check what MSE we get for random predictions. 
# If this is not significantly worse than for our true predictions, something is wrong!

from numpy.random import permutation

print("Test: ", (mean_squared_error(test_set_targets,test_predictions)))
print("Test_Random: ", (mean_squared_error(permutation(test_set_targets),test_predictions)))
print("Train: ", (mean_squared_error(train_set_targets,train_predictions)))
print("Train_Random: ", (mean_squared_error(permutation(train_set_targets),train_predictions)))
# Out:
# Test:  0.026706323988387435
# Test_Random:  1.9354181380707731
# Train:  0.027400101424799747
# Train_Random:  1.9988147738340987

# %% [markdown]
# # AutoRegression model instead linear

# %%
#from statsmodels.tsa.ar_model import AutoReg
#from random import random

# %%
#auto_reg_model = AutoReg(train_set_targets, exog = train_set_features, lags=1)

# %%
#auto_reg_model_fit = auto_reg_model.fit()
#auto_reg_model_fit.summary()

#auto_reg_model_fit.params

#predictions = auto_reg_model_fit.predict(start=len(train_set_features), end=len(train_set_features)+len(t_set_features)-1, dynamic=False)

#yhat = auto_reg_model.predict(auto_reg_model_fit, 50, 51)
#print(yhat)

# %%
# Multiple Regressors

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(kernel='rbf',C=10,gamma=0.01),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.LinearRegression(),
    #linear_model.TheilSenRegressor()
    ]



for item in classifiers:
    print(item)
    clf = item
    clf.fit(train_set_features, train_set_targets)
    ypredtrain = (clf.predict(train_set_features))
    ypredtest = (clf.predict(test_set_features))
    print("Test: ", (mean_squared_error(test_set_targets,ypredtest)))
    print("Test_Random: ", (mean_squared_error(permutation(test_set_targets),ypredtest)))
    print("Train: ", (mean_squared_error(train_set_targets,ypredtrain)))
    print("Train_Random: ", (mean_squared_error(permutation(train_set_targets),ypredtrain)), '\n')
# Out:
# SVR(C=10, gamma=0.01)
# Test:  0.021593660126220316
# Test_Random:  1.9193122392921167
# Train:  0.015659120059701943
# Train_Random:  1.9824758617763094
#
# SGDRegressor()
# Test:  0.027064127238402378
# Test_Random:  1.955686538629849
# Train:  0.028482171580499992
# Train_Random:  1.9996106196466084
#
# BayesianRidge()
# Test:  0.026682623487975718
# Test_Random:  1.9039366512364055
# Train:  0.027401494665354985
# Train_Random:  1.9474152760259549
#
# LassoLars()
# Test:  0.9881258371100586
# Test_Random:  0.9881258371100586
# Train:  1.002974382200291
# Train_Random:  1.002974382200291
#
# ARDRegression()
# Test:  0.02676330255755273
# Test_Random:  1.8910407134961071
# Train:  0.027519642406836093
# Train_Random:  1.98748422773575
#
# PassiveAggressiveRegressor()
# Test:  0.035319369539698026
# Test_Random:  1.9158210776200801
# Train:  0.03760931423871059
# Train_Random:  1.9896976068140813
#
# LinearRegression()
# Test:  0.026706323988387435
# Test_Random:  1.9759264422983587
# Train:  0.027400101424799747
# Train_Random:  1.97908781990301

# %%
train
# Out:
#              0         1         2         3         4         5         6  \
# 0     1.473380  1.302358  0.955648  0.507111 -0.010355 -0.393880 -0.530256
# 1     1.424475  1.115568  0.739882  0.400290  0.279887 -0.132578 -0.211899
# 2     1.305604  1.178813  1.466944  1.360661  1.251295  0.914605  1.034285
# 3     0.002807 -0.221519 -0.083365 -0.207559 -0.556045 -0.971370 -1.415740
# 4     0.849331  1.231393  0.801866  0.847607  0.670850  0.497142  0.205616
# ...        ...       ...       ...       ...       ...       ...       ...
# 7321  1.876208  1.883376  1.831151  1.836686  1.816896  1.803459  1.704366
# 7322  1.999932  2.012557  1.977732  1.980653  1.961981  1.904541  1.897345
# 7323  1.827227  1.827655  1.797092  1.777848  1.756158  1.714139  1.680463
# 7324  1.589435  1.590090  1.605195  1.591595  1.581007  1.550989  1.531828
# 7325  2.167003  2.168932  2.120908  2.113237  2.090573  2.073883  2.086083
#
#              7         8         9  ...        40        41        42  \
# 0    -0.823445 -0.765791 -0.164422  ...  1.177141  1.395390  1.641736
# 1    -0.428109 -0.437151  0.383196  ...  0.673348  0.807094  1.004954
# 2     0.899520  0.748029  0.661196  ...  1.657412  1.623164  1.533968
# 3    -1.760730 -1.883560 -2.516417  ... -0.542988 -0.501347 -0.818187
# 4     0.252102  0.391566  0.247023  ... -0.271387 -0.718060 -0.293903
# ...        ...       ...       ...  ...       ...       ...       ...
# 7321  1.566069  1.618514  1.600551  ...  1.240904  1.232736  1.211619
# 0    -1.237740 -1.021422 -0.986630 -0.654230 -0.376322 -0.508761 -0.511324
# 1     1.127021  0.822584  0.779954  0.476809  0.566257  0.260047  0.138926
# 2     0.631203  0.413616  0.787361  0.894501  1.224173  1.385366  1.643954
# 3    -1.413689 -1.806222 -1.728791 -1.950228 -1.776211 -1.836083 -1.288752
# 4     0.385968  0.179167  0.355158  0.648174  0.958568  1.206558  1.288894
# ...        ...       ...       ...       ...       ...       ...       ...
# 3136  1.108725  1.108073  1.076528  1.046762  1.024985  1.017597  0.986699
# 3137  1.215157  1.192857  1.169250  1.141640  1.117284  1.094859  1.063913
# 3138  1.216083  1.181057  1.157599  1.131852  1.115997  1.096159  1.075811
# 3139  1.321846  1.317345  1.283794  1.262193  1.242726  1.215442  1.170270
# 3140  1.308922  1.295342  1.243643  1.235923  1.212869  1.178078  1.154978
#
# [3141 rows x 50 columns]

# %%
lin_reg = svm.SVR(kernel='rbf',C=10,gamma=0.01).fit(train, targets)

ypredtest = (lin_reg.predict(test))

# %%
np.savetxt('myfileidk2.txt', np.c_[ypredtest])

# %%
for item in classifiers:
    print(item)
    clf = item
    clf.fit(train_set_features, train_set_targets)
    scores = cross_val_score(clf, train_set_features, train_set_targets, cv=5)
    print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# SVR(C=10, gamma=0.01)
# 0.98 accuracy with a standard deviation of 0.00
# SGDRegressor()
# 0.97 accuracy with a standard deviation of 0.00
# BayesianRidge()
# 0.97 accuracy with a standard deviation of 0.00
# LassoLars()
# -0.00 accuracy with a standard deviation of 0.00
# ARDRegression()
# 0.97 accuracy with a standard deviation of 0.00
# PassiveAggressiveRegressor()
# 0.96 accuracy with a standard deviation of 0.01
# LinearRegression()
# 0.97 accuracy with a standard deviation of 0.00

# %%
# Importing the Keras libraries and packages
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
#tf.config.list_physical_devices('GPU')

# %%
X = train_set_features.values.reshape(5860,50,1)
y = train_set_targets.values.reshape(5860,1,1)

# %%
# Initialising the RNN
regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 30, return_sequences = True, input_shape = (X.shape[1], 1)))
regressor.add(Dropout(0.5))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 10, return_sequences = True))
regressor.add(Dropout(0.3))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 5))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
regressor.fit(X, y, epochs = 50, batch_size = 16)
# Out:
# Train on 5860 samples
# Epoch 1/50
# 5860/5860 [==============================] - 46s 8ms/sample - loss: 0.1007
# Epoch 2/50
# 5860/5860 [==============================] - 42s 7ms/sample - loss: 0.0998
# Epoch 3/50
# 5860/5860 [==============================] - 41s 7ms/sample - loss: 0.0969
# Epoch 4/50
# 5860/5860 [==============================] - 41s 7ms/sample - loss: 0.0960
# Epoch 5/50
# 5860/5860 [==============================] - 62s 11ms/sample - loss: 0.0941
# Epoch 6/50
# 5860/5860 [==============================] - 41s 7ms/sample - loss: 0.0957
# Epoch 7/50
# 5860/5860 [==============================] - 42s 7ms/sample - loss: 0.0957
# Epoch 8/50
# 5860/5860 [==============================] - 42s 7ms/sample - loss: 0.0967
# Epoch 9/50
# 5860/5860 [==============================] - 43s 7ms/sample - loss: 0.0948
# Epoch 10/50
# 5860/5860 [==============================] - 43s 7ms/sample - loss: 0.0929
# Epoch 11/50
# 5860/5860 [==============================] - 43s 7ms/sample - loss: 0.0897
# Epoch 12/50
# 5860/5860 [==============================] - 43s 7ms/sample - loss: 0.0958
# Epoch 13/50
# 5860/5860 [==============================] - 43s 7ms/sample - loss: 0.0997
# Epoch 14/50
# 5860/5860 [==============================] - 43s 7ms/sample - loss: 0.0936
# Epoch 15/50
# 5860/5860 [==============================] - 44s 7ms/sample - loss: 0.0956
# Epoch 16/50
# 4352/5860 [=====================>........] - ETA: 11s - loss: 0.0942
